# %%
print("Welcoe to Dominos")
print("what pizza do you want")

# %%
pizza = {1 : {'name': 'extraVigenza', 'price_lr': 350, 'price_md': 250, 'price_rg': 150},
         2 : {'name': 'cloud 8', 'price_lr': 450, 'price_md': 350, 'price_rg': 250},
         3 : {'name': 'pepepaneer', 'price_lr': 500, 'price_md': 339, 'price_rg': 199},
         4 : {'name': 'S peeper', 'price_lr': 490, 'price_md': 290, 'price_rg': 200},
         5 : {'name': 'Farmhouse', 'price_lr': 700, 'price_md': 400, 'price_rg': 220}}

# %%
size = {1 : "price_lr",
        2 : "price_md",
        3 : "price_rg"}

# %%
ui_pz    = int(input("Enter your choice of pizza : "))
ui_sz    = int(input("what shoud be the size : "))
ui_qt    = int(input("how many pizzzas do you wan t "))
ui_name  = input("enter your name : ")
ui_mail  = input("enter yout e-mail address : ")
ui_phone = int(input("enter your phone number : "))

print("-----------------------------")
print("Customer Details : ",
       )
print("-----------------------------")
print("name     : ", pizza[ui_pz]["name"])
print("price    : ",pizza[ui_pz][size[ui_sz]])
print("quantity : ",ui_qt)
print("-----------------------------")

print("Billing Amount : ", ui_qt * pizza[ui_pz][size[ui_sz]])
print("-----------------------------")
